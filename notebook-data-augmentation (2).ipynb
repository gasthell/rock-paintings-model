# %%
import os
import cv2
import numpy as np
from patchmatch import patch_match

png_images = []
data_folder = 'data'

for filename in os.listdir(data_folder):
    if filename.lower().endswith('.png'):
        img_path = os.path.join(data_folder, filename)
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        png_images.append(img)

# %%
def process_and_inpaint(image, canvas_width=512, canvas_height=512, save_path=None):
    """
    Resizes an image to fit on a canvas, places it in the center,
    and inpaints the surrounding empty space.
    """

    original_height, original_width = image.shape[:2]

    # Calculate the scaling factor to fit the image on the canvas
    # while maintaining the aspect ratio.
    scale = min(canvas_width / original_width, canvas_height / original_height)
    new_width = int(original_width * scale)
    new_height = int(original_height * scale)

    # Resize the image
    resized_image = cv2.resize(image, (new_width, new_height))

    # Create a black canvas
    canvas = np.zeros((canvas_height, canvas_width, 3), dtype=np.uint8)

    # Calculate the position to paste the resized image to be in the center
    x_offset = (canvas_width - new_width) // 2
    y_offset = (canvas_height - new_height) // 2

    # Paste the resized image onto the canvas
    canvas[y_offset:y_offset+new_height, x_offset:x_offset+new_width] = resized_image

    # Create a mask for the empty space around the image.
    # The mask should be white (255) where we want to inpaint.
    mask = np.ones((canvas_height, canvas_width), dtype=np.uint8) * 255
    mask[y_offset:y_offset+new_height, x_offset:x_offset+new_width] = 0

    # Perform content-aware fill using PatchMatch
    print(f"Inpainting the borders for {save_path}...")
    inpainted_image = patch_match.inpaint(canvas, mask, patch_size=7)

    # Save the resulting image
    dir_name, file_name = os.path.split(save_path)
    output_filename = os.path.join(dir_name, f"{file_name}")
    cv2.imwrite(output_filename, inpainted_image)
    print(f"Processing complete. Result saved as '{output_filename}'")

# %%
i = 1
for image in png_images:
    process_and_inpaint(image, 512, 512, save_path=f'augmented_data/{i}.png')
    i += 1
# Out:
# Inpainting the borders for augmented_data/1.png...
# Processing complete. Result saved as 'augmented_data\1.png'
# Inpainting the borders for augmented_data/2.png...
# Processing complete. Result saved as 'augmented_data\2.png'
# Inpainting the borders for augmented_data/3.png...
# Processing complete. Result saved as 'augmented_data\3.png'
# Inpainting the borders for augmented_data/4.png...
# Processing complete. Result saved as 'augmented_data\4.png'
# Inpainting the borders for augmented_data/5.png...
# Processing complete. Result saved as 'augmented_data\5.png'
# Inpainting the borders for augmented_data/6.png...
# Processing complete. Result saved as 'augmented_data\6.png'
# Inpainting the borders for augmented_data/7.png...
# Processing complete. Result saved as 'augmented_data\7.png'
# Inpainting the borders for augmented_data/8.png...
# Processing complete. Result saved as 'augmented_data\8.png'
# Inpainting the borders for augmented_data/9.png...
# Processing complete. Result saved as 'augmented_data\9.png'
# Inpainting the borders for augmented_data/10.png...
# Processing complete. Result saved as 'augmented_data\10.png'
# Inpainting the borders for augmented_data/11.png...
# Processing complete. Result saved as 'augmented_data\11.png'
# Inpainting the borders for augmented_data/12.png...
# Processing complete. Result saved as 'augmented_data\12.png'
# Inpainting the borders for augmented_data/13.png...
# Processing complete. Result saved as 'augmented_data\13.png'
# Inpainting the borders for augmented_data/14.png...
# Processing complete. Result saved as 'augmented_data\14.png'
# Inpainting the borders for augmented_data/15.png...
# Processing complete. Result saved as 'augmented_data\15.png'
# Inpainting the borders for augmented_data/16.png...
# Processing complete. Result saved as 'augmented_data\16.png'
# Inpainting the borders for augmented_data/17.png...
# Processing complete. Result saved as 'augmented_data\17.png'
# Inpainting the borders for augmented_data/18.png...
# Processing complete. Result saved as 'augmented_data\18.png'
# Inpainting the borders for augmented_data/19.png...
# Processing complete. Result saved as 'augmented_data\19.png'
# Inpainting the borders for augmented_data/20.png...
# Processing complete. Result saved as 'augmented_data\20.png'
# Inpainting the borders for augmented_data/21.png...
# Processing complete. Result saved as 'augmented_data\21.png'
# Inpainting the borders for augmented_data/22.png...
# Processing complete. Result saved as 'augmented_data\22.png'
# Inpainting the borders for augmented_data/23.png...
# Processing complete. Result saved as 'augmented_data\23.png'
# Inpainting the borders for augmented_data/24.png...
# Processing complete. Result saved as 'augmented_data\24.png'
# Inpainting the borders for augmented_data/25.png...
# Processing complete. Result saved as 'augmented_data\25.png'
# Inpainting the borders for augmented_data/26.png...
# Processing complete. Result saved as 'augmented_data\26.png'
# Inpainting the borders for augmented_data/27.png...
# Processing complete. Result saved as 'augmented_data\27.png'
# Inpainting the borders for augmented_data/28.png...
# Processing complete. Result saved as 'augmented_data\28.png'
# Inpainting the borders for augmented_data/29.png...
# Processing complete. Result saved as 'augmented_data\29.png'
# Inpainting the borders for augmented_data/30.png...
# Processing complete. Result saved as 'augmented_data\30.png'
# Inpainting the borders for augmented_data/31.png...
# Processing complete. Result saved as 'augmented_data\31.png'
# Inpainting the borders for augmented_data/32.png...
# Processing complete. Result saved as 'augmented_data\32.png'
# Inpainting the borders for augmented_data/33.png...
# Processing complete. Result saved as 'augmented_data\33.png'
# Inpainting the borders for augmented_data/34.png...
# Processing complete. Result saved as 'augmented_data\34.png'
# Inpainting the borders for augmented_data/35.png...
# Processing complete. Result saved as 'augmented_data\35.png'
# Inpainting the borders for augmented_data/36.png...
# Processing complete. Result saved as 'augmented_data\36.png'
# Inpainting the borders for augmented_data/37.png...
# Processing complete. Result saved as 'augmented_data\37.png'
# Inpainting the borders for augmented_data/38.png...
# Processing complete. Result saved as 'augmented_data\38.png'
# Inpainting the borders for augmented_data/39.png...
# Processing complete. Result saved as 'augmented_data\39.png'
# Inpainting the borders for augmented_data/40.png...
# Processing complete. Result saved as 'augmented_data\40.png'
# Inpainting the borders for augmented_data/41.png...
# Processing complete. Result saved as 'augmented_data\41.png'
# Inpainting the borders for augmented_data/42.png...
# Processing complete. Result saved as 'augmented_data\42.png'
# Inpainting the borders for augmented_data/43.png...
# Processing complete. Result saved as 'augmented_data\43.png'
# Inpainting the borders for augmented_data/44.png...
# Processing complete. Result saved as 'augmented_data\44.png'
# Inpainting the borders for augmented_data/45.png...
# Processing complete. Result saved as 'augmented_data\45.png'
# Inpainting the borders for augmented_data/46.png...
# Processing complete. Result saved as 'augmented_data\46.png'
# Inpainting the borders for augmented_data/47.png...
# Processing complete. Result saved as 'augmented_data\47.png'
# Inpainting the borders for augmented_data/48.png...
# Processing complete. Result saved as 'augmented_data\48.png'
# Inpainting the borders for augmented_data/49.png...
# Processing complete. Result saved as 'augmented_data\49.png'
# Inpainting the borders for augmented_data/50.png...
# Processing complete. Result saved as 'augmented_data\50.png'
# Inpainting the borders for augmented_data/51.png...
# Processing complete. Result saved as 'augmented_data\51.png'
# Inpainting the borders for augmented_data/52.png...
# Processing complete. Result saved as 'augmented_data\52.png'
# Inpainting the borders for augmented_data/53.png...
# Processing complete. Result saved as 'augmented_data\53.png'
# Inpainting the borders for augmented_data/54.png...
# Processing complete. Result saved as 'augmented_data\54.png'
# Inpainting the borders for augmented_data/55.png...
# Processing complete. Result saved as 'augmented_data\55.png'
# Inpainting the borders for augmented_data/56.png...
# Processing complete. Result saved as 'augmented_data\56.png'
# Inpainting the borders for augmented_data/57.png...
# Processing complete. Result saved as 'augmented_data\57.png'
# Inpainting the borders for augmented_data/58.png...
# Processing complete. Result saved as 'augmented_data\58.png'
# Inpainting the borders for augmented_data/59.png...
# Processing complete. Result saved as 'augmented_data\59.png'
# Inpainting the borders for augmented_data/60.png...
# Processing complete. Result saved as 'augmented_data\60.png'
# Inpainting the borders for augmented_data/61.png...
# Processing complete. Result saved as 'augmented_data\61.png'
# Inpainting the borders for augmented_data/62.png...
# Processing complete. Result saved as 'augmented_data\62.png'
# Inpainting the borders for augmented_data/63.png...
# Processing complete. Result saved as 'augmented_data\63.png'
# Inpainting the borders for augmented_data/64.png...
# Processing complete. Result saved as 'augmented_data\64.png'
# Inpainting the borders for augmented_data/65.png...
# Processing complete. Result saved as 'augmented_data\65.png'
# Inpainting the borders for augmented_data/66.png...
# Processing complete. Result saved as 'augmented_data\66.png'
# Inpainting the borders for augmented_data/67.png...
# Processing complete. Result saved as 'augmented_data\67.png'
# Inpainting the borders for augmented_data/68.png...
# Processing complete. Result saved as 'augmented_data\68.png'
# Inpainting the borders for augmented_data/69.png...
# Processing complete. Result saved as 'augmented_data\69.png'
# Inpainting the borders for augmented_data/70.png...
# Processing complete. Result saved as 'augmented_data\70.png'
# Inpainting the borders for augmented_data/71.png...
# Processing complete. Result saved as 'augmented_data\71.png'
# Inpainting the borders for augmented_data/72.png...
# Processing complete. Result saved as 'augmented_data\72.png'
# Inpainting the borders for augmented_data/73.png...
# Processing complete. Result saved as 'augmented_data\73.png'
# Inpainting the borders for augmented_data/74.png...
# Processing complete. Result saved as 'augmented_data\74.png'
# Inpainting the borders for augmented_data/75.png...
# Processing complete. Result saved as 'augmented_data\75.png'
# Inpainting the borders for augmented_data/76.png...
# Processing complete. Result saved as 'augmented_data\76.png'
